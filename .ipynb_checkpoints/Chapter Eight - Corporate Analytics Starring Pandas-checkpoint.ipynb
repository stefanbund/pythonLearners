# %% [markdown]
# ## Introducing Business Computing, and Corporate Analytics
#
# lets combine the sales from all stores into a discreet data set, and see where we go.
#
# ### Summarizing Progress to Date
#
# the following represents a microcosm of the work you've done, then we add a new concept: the corporation class.

# %%
import random

# %%
# Define a class for purchase of a cone
class Purchase:
    # Initialize a sale with a total amount
    def __init__(self):
        self.total = 0

    # Increment the total amount by a given price
    def increment(self, price):
        self.total += price

    # Return the total amount of the sale
    def __str__(self):
        return "Sale: $" + str(self.total)

# %%
flavors = ["vanilla", "chocolate", "strawberry", "mint", "caramel", "coffee", "lemon", "coconut", "banana"]
sizes = ["small", "medium", "large"]

class Inventory:
    def __init__(self):
        self.cones = []

        num_cones = random.randint(10, 20) # Generate a random number of products between 10 and 20
        
        for i in range(num_cones):
            flavor = random.choice(flavors) # make a flavor
            size = random.choice(sizes) #make a size
            cone = IceCreamCone(flavor, size) #make a cone with your values
            self.cones.append(cone)
              
    def add_cone(self, cone): # Add an IceCreamCone to the order
        self.cones.append(cone)

    def display_order(self): # Display all cones in the order
        for cone in self.cones:
            print(cone)

# %%
class IceCreamCone:
    def __init__(self, flavor, size):
        
        #NEW: price
        self.price = round(random.uniform(1, 10), 2)

        self.flavor = random.choice(flavors)
        self.size = random.choice(sizes)

    def __str__(self):
        return f'Flavor: {self.flavor}, Size: {self.size}'

# %%
class Stand:
    def __init__(self, name): # Initialize a store with a name, an inventory, a list of customers
        self.name = name
        self.inventory = Inventory()
        self.customers = []
        
        #NEW: buy things and add their number
        self.purchase = Purchase()


    def add_customer(self, customer): # Add a customer to the store
        self.customers.append(customer)
        
    def getCustomers(self):
        for customer in self.customers:
            print("customer " + customer.getName() + " is busy shopping.")
    
    def run(self): # Run the simulation for the store
        print("Welcome to " + self.name + "!")
        print(self.inventory.display_order())
        print("We have " + str(len(self.customers)) + " customers today.")
        
        for customer in self.customers: # Iterate over the customers
            print("Customer " + customer.name + " is shopping.")
            # Take one item from the inventory and add it to the customer's basket
            item = random.choice(self.inventory.cones)
            customer.add_to_order(item)
            print("Customer " + customer.name + " added " + str(item) + " to their order.")
            
            # NEW : CREATE the ability to purchase things, and add that to a total
            self.purchase.increment(item.price) # Increment the sale object with the price of the item
            print("Customer " + customer.name + " checked out and paid $" + str(item.price) + ".")
        print("The total sales for " + self.name + " today is $" + str(self.purchase.total) + ".")

    # Return the name and the sale object of the store
    def __str__(self):
        return self.name + " (Sales: $" + str(self.purchase.total) + ")"

# Define a class for customer
class Customer:
    
    def __init__(self, name): # Initialize a customer with a name and a basket
        self.name = name
        self.order = Order()
        
    def getName(self):
            return self.name
    
    def add_to_order(self, product): # Add a product to the customer's basket
        self.order.add(product)

    # Return the name and the basket of the customer
    def __str__(self):
        return self.name + " (" + str(self.order) + ")"

class Order: #slight variation on the store idea, where you might do a 'Basket'
    
    def __init__(self): # Initialize a basket with a list of products
        self.products = []
    
    def add(self, product): # Add a product to the order
        self.products.append(product)

    def __str__(self): # Return the list of products in the order
        result = "Order:\n"
        for product in self.products:
            result += str(product) + "\n"
        return result

# %%
# stand = Stand("Alabama Street Ice Creamery")

# names = ["Alice","Bob","Charlie","David","Eve","Frank","Grace","Harry","Ivy","Jack"]
# for i in range(len(names)):
#     stand.add_customer(Customer(names[i])) #adds customers to the store/stand

# stand.getCustomers()

# stand.run()

# %% [markdown]
# ## new class: analytics
#
# its job is to collect total sales from each store and save them to csv

# %%
# !pip install pandas
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: pandas in /home/stefan/snap/jupyter/common/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /snap/jupyter/6/lib/python3.7/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in /home/stefan/snap/jupyter/common/lib/python3.7/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/stefan/snap/jupyter/common/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /snap/jupyter/6/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

class Analytics:
    def __init__(self):
        self.store_analytics = []
    
    def add_analytics(self, analytics):  #send it your collected store results
        self.store_analytics.append(analytics)
    
    def make_csv(self):
        df = pd.DataFrame(self.store_analytics)
        print(df)
        entitle = "latest-store.csv"  #title for the file we'll build from it
        df.to_csv(entitle)

# %%
# Define a class for corporation
class Organization:
    # Initialize a corporation with a name and a list of stores
    def __init__(self, name):
        self.name = name
        self.stands = []
        
        #NEW
        self.analytics = []

    # Add a store to the corporation
    def add_stand(self, stand):
        self.stands.append(stand)

    # Run the simulation for the corporation
    def simulate(self):
        print("Welcome to " + self.name + "!")
        print("We have " + str(len(self.stands)) + " stores in our corporation.")
        # Iterate over the stores
        for stand in self.stands:
            # Run the simulation for each store
            stand.run()
            
        # Calculate the total sales for the corporation
        total_sales = 0
        for stand in self.stands:
            total_sales += stand.purchase.total
#new
            dict_A = {"name":stand.name, "total_sales":stand.purchase.total}
            self.analytics.append(dict_A)
        print("The total sales for " + self.name + " today is $" + str(total_sales) + ".")

    #new
    def get_analytics(self):
        return self.analytics
    
    #new
    def display_analytics(self):
        for i in self.analytics:
            print(i )

    # Return the name and the list of stores of the corporation
    def __str__(self):
        result = self.name + ":\n"
        for stnd in self.stands:
            result += str(stand) + "\n"
        return result

# Create a corporation object
corp = Organization("Your-Name Organization")

# Create some store objects and add them to the corporation
store1 = Stand("Neighborhood Store 1")
store2 = Stand("Neighborhood Store 2")
store3 = Stand("Neighborhood Store 3")
corp.add_stand(store1)
corp.add_stand(store2)
corp.add_stand(store3)

# Create some customer objects and add them to the stores
customer1 = Customer("Alice")
customer2 = Customer("Bob")
customer3 = Customer("Charlie")
customer4 = Customer("David")
customer5 = Customer("Eve")
customer6 = Customer("Frank")
customer7 = Customer("Grace")
customer8 = Customer("Harry")
customer9 = Customer("Ivy")
customer10 = Customer("Jack")
store1.add_customer(customer1)
store1.add_customer(customer2)
store2.add_customer(customer3)
store2.add_customer(customer4)
store2.add_customer(customer5)
store3.add_customer(customer6)
store3.add_customer(customer7)
store3.add_customer(customer8)
store3.add_customer(customer9)
store3.add_customer(customer10)
corp.simulate()

corp.display_analytics()

analytic = Analytics()
analytic.add_analytics(corp.get_analytics())
analytic.make_csv()  #output the results from a simulation as csv locally
# Out:
# Welcome to Your-Name Organization!
# We have 3 stores in our corporation.
# Welcome to Neighborhood Store 1!
# Flavor: coconut, Size: small
# Flavor: strawberry, Size: large
# Flavor: chocolate, Size: large
# Flavor: banana, Size: large
# Flavor: coffee, Size: large
# Flavor: lemon, Size: small
# Flavor: caramel, Size: large
# Flavor: strawberry, Size: small
# Flavor: strawberry, Size: large
# Flavor: coffee, Size: medium
# Flavor: coffee, Size: small
# Flavor: coconut, Size: large
# Flavor: caramel, Size: large
# Flavor: banana, Size: medium
# Flavor: coffee, Size: large
# Flavor: coconut, Size: small
# Flavor: banana, Size: large
# Flavor: chocolate, Size: large
# Flavor: strawberry, Size: large
# None
# We have 2 customers today.
# Customer Alice is shopping.
# Customer Alice added Flavor: banana, Size: medium to their order.
# Customer Alice checked out and paid $2.28.
# Customer Bob is shopping.
# Customer Bob added Flavor: strawberry, Size: large to their order.
# Customer Bob checked out and paid $3.25.
# The total sales for Neighborhood Store 1 today is $5.529999999999999.
# Welcome to Neighborhood Store 2!
# Flavor: caramel, Size: medium
# Flavor: coffee, Size: small
# Flavor: banana, Size: medium
# Flavor: chocolate, Size: large
# Flavor: lemon, Size: small
# Flavor: vanilla, Size: large
# Flavor: coffee, Size: medium
# Flavor: caramel, Size: large
# Flavor: caramel, Size: small
# Flavor: caramel, Size: small
# Flavor: strawberry, Size: large
# Flavor: coconut, Size: medium
# Flavor: strawberry, Size: small
# Flavor: coconut, Size: large
# Flavor: strawberry, Size: large
# Flavor: chocolate, Size: small
# Flavor: coffee, Size: large
# Flavor: strawberry, Size: medium
# None
# We have 3 customers today.
# Customer Charlie is shopping.
# Customer Charlie added Flavor: coconut, Size: medium to their order.
# Customer Charlie checked out and paid $9.43.
# Customer David is shopping.
# Customer David added Flavor: coconut, Size: medium to their order.
# Customer David checked out and paid $9.43.
# Customer Eve is shopping.
# Customer Eve added Flavor: chocolate, Size: small to their order.
# Customer Eve checked out and paid $6.91.
# The total sales for Neighborhood Store 2 today is $25.77.
# Welcome to Neighborhood Store 3!
# Flavor: lemon, Size: medium
# Flavor: vanilla, Size: large
# Flavor: coconut, Size: large
# Flavor: vanilla, Size: medium
# Flavor: vanilla, Size: small
# Flavor: caramel, Size: large
# Flavor: coconut, Size: medium
# Flavor: coffee, Size: medium
# Flavor: vanilla, Size: small
# Flavor: caramel, Size: medium
# Flavor: vanilla, Size: medium
# Flavor: lemon, Size: small
# Flavor: lemon, Size: small
# Flavor: coconut, Size: large
# Flavor: mint, Size: medium
# Flavor: vanilla, Size: medium
# Flavor: vanilla, Size: large
# Flavor: strawberry, Size: medium
# None
# We have 5 customers today.
# Customer Frank is shopping.
# Customer Frank added Flavor: mint, Size: medium to their order.
# Customer Frank checked out and paid $4.83.
# Customer Grace is shopping.
# Customer Grace added Flavor: strawberry, Size: medium to their order.
# Customer Grace checked out and paid $6.53.
# Customer Harry is shopping.
# Customer Harry added Flavor: caramel, Size: large to their order.
# Customer Harry checked out and paid $8.26.
# Customer Ivy is shopping.
# Customer Ivy added Flavor: caramel, Size: medium to their order.
# Customer Ivy checked out and paid $7.73.
# Customer Jack is shopping.
# Customer Jack added Flavor: lemon, Size: small to their order.
# Customer Jack checked out and paid $6.11.
# The total sales for Neighborhood Store 3 today is $33.46.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-0bf0f6c4fde1> in <module>
#      79 store3.add_customer(customer9)
#      80 store3.add_customer(customer10)
# ---> 81 corp.simulate()
#      82
#      83 corp.display_analytics()
#
# <ipython-input-34-0bf0f6c4fde1> in simulate(self)
#      27             total_sales += stand.purchase.total
#      28 #new
# ---> 29             dict_A = {name:stand.name, total_sales:stand.purchase.total}
#      30             self.analytics.append(dict_A)
#      31         print("The total sales for " + self.name + " today is $" + str(total_sales) + ".")
#
# NameError: name 'name' is not defined
